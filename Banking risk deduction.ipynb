# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df = pd.read_csv("C:/Users/HP/Downloads/Banking.csv")
df.head(5)
# Out:
#   Client ID             Name  Age  Location ID Joined Bank   Banking Contact  \
# 0  IND81288    Raymond Mills   24        34324  06-05-2019    Anthony Torres
# 1  IND65833    Julia Spencer   23        42205  10-12-2001  Jonathan Hawkins
# 2  IND47499   Stephen Murray   27         7314  25-01-2010     Anthony Berry
# 3  IND72498   Virginia Garza   40        34594  28-03-2019        Steve Diaz
# 4  IND60181  Melissa Sanders   46        41269  20-07-2012        Shawn Long
#
#   Nationality            Occupation Fee Structure Loyalty Classification  ...  \
# 0    American  Safety Technician IV          High                   Jade  ...
# 1     African   Software Consultant          High                   Jade  ...
# 2    European    Help Desk Operator          High                   Gold  ...
# 3    American          Geologist II           Mid                 Silver  ...
# 4    American   Assistant Professor           Mid               Platinum  ...
#
# ...

# %%
pip install psycopg2-binary sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine 
# 1: Connect to postgerys

username = 'postgres'
password = '1k2e3v4i5N'
host = 'localhost'
port = '5432'
database = "banking_cases"

engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")

#2 : Load Dataframe into PGAdmin

table_name = "banking_customer"
df.to_sql(table_name , engine , if_exists = "replace", index = False)

print(f"Data successfully loaded into table '{table_name}' in database '{database}'.")
# Out:
# Data successfully loaded into table 'banking_customer' in database 'banking_cases'.

# %%
# Generate discriptive statistics for the Data frame :

df.describe()
# Out:
#                Age   Location ID  Estimated Income  Superannuation Savings  \
# count  3000.000000   3000.000000       3000.000000             3000.000000
# mean     51.039667  21563.323000     171305.034263            25531.599673
# std      19.854760  12462.273017     111935.808209            16259.950770
# min      17.000000     12.000000      15919.480000             1482.030000
# 25%      34.000000  10803.500000      82906.595000            12513.775000
# 50%      51.000000  21129.500000     142313.480000            22357.355000
# 75%      69.000000  32054.500000     242290.305000            35464.740000
# max      85.000000  43369.000000     522330.260000            75963.900000
#
#        Amount of Credit Cards  Credit Card Balance    Bank Loans  \
# count             3000.000000          3000.000000  3.000000e+03
# mean                 1.463667          3176.206943  5.913862e+05
# std                  0.676387          2497.094709  4.575570e+05
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Client ID                 3000 non-null   object
#  1   Name                      3000 non-null   object
#  2   Age                       3000 non-null   int64
#  3   Location ID               3000 non-null   int64
#  4   Joined Bank               3000 non-null   object
#  5   Banking Contact           3000 non-null   object
#  6   Nationality               3000 non-null   object
#  7   Occupation                3000 non-null   object
#  8   Fee Structure             3000 non-null   object
#  9   Loyalty Classification    3000 non-null   object
#  10  Estimated Income          3000 non-null   float64
#  11  Superannuation Savings    3000 non-null   float64
#  12  Amount of Credit Cards    3000 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['Client ID', 'Name', 'Age', 'Location ID', 'Joined Bank',
#        'Banking Contact', 'Nationality', 'Occupation', 'Fee Structure',
#        'Loyalty Classification', 'Estimated Income', 'Superannuation Savings',
#        'Amount of Credit Cards', 'Credit Card Balance', 'Bank Loans',
#        'Bank Deposits', 'Checking Accounts', 'Saving Accounts',
#        'Foreign Currency Account', 'Business Lending', 'Properties Owned',
#        'Risk Weighting', 'BRId', 'GenderId', 'IAId'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ','_')

# %%
df.columns
# Out:
# Index(['client_id', 'name', 'age', 'location_id', 'joined_bank',
#        'banking_contact', 'nationality', 'occupation', 'fee_structure',
#        'loyalty_classification', 'estimated_income', 'superannuation_savings',
#        'amount_of_credit_cards', 'credit_card_balance', 'bank_loans',
#        'bank_deposits', 'checking_accounts', 'saving_accounts',
#        'foreign_currency_account', 'business_lending', 'properties_owned',
#        'risk_weighting', 'brid', 'genderid', 'iaid'],
#       dtype='object')

# %%
# freqency mapping for gender
ferquency_mapping = {
    
    1 : 'male',
    2 : 'female'
}

df['gender'] = df['genderid'].map(ferquency_mapping)

# %%
df[['gender','genderid']].head(5)
# Out:
#    gender  genderid
# 0    male         1
# 1    male         1
# 2  female         2
# 3    male         1
# 4  female         2

# %%
# frequency mapping for IAID 

ferquency_mapping1 = {
    
    1 : 'Victor_Dean',
    2 : 'Jeremy_Potter',
    3 : 'Emest_Knight',
    4 : 'Eric_shaw',
    5 : 'Kevin_kim',
    6 : 'Victor_Roger',
    7 : 'Eugene_Cunninghan',
    8 : 'joe_carroll',
    9 : 'Steve_Sanchez',
    10 : 'Lawrence_Sanchez',
    11 : 'Peter_Castillo',
    12 : 'Victor_gutlierrez',
    13 : 'Daniel_Carroll',
    14 : 'Carl_Anderson',
    15 : 'Nicholas_Ward',
    16 : 'Fred_Bryant',
    17 : 'Ryan_Taylor',
    18 : 'Sean_Vasquez',
    19 : 'Nicholas_Morrison',
    20 : 'Jack_Phillips',
    21 : 'Juan_Ramirez',
    22 : 'Gregory_boyd'
}

df['ivestment_advisor'] = df['iaid'].map(ferquency_mapping1)

# %%
df[['iaid' , 'ivestment_advisor']].tail(10)
# Out:
#       iaid  ivestment_advisor
# 2990    14      Carl_Anderson
# 2991    15      Nicholas_Ward
# 2992     1        Victor_Dean
# 2993     2      Jeremy_Potter
# 2994     3       Emest_Knight
# 2995     4          Eric_shaw
# 2996     5          Kevin_kim
# 2997     6       Victor_Roger
# 2998     7  Eugene_Cunninghan
# 2999     8        joe_carroll

# %%
# frequency mapping for Banking_Relationship

ferquency_mapping2 = {
    1 : 'Retail',
    2 : 'Institutional',
    3 : 'Pricvate_Bank',
    4 : 'Commercial'
}

df['banking_relationship'] = df['brid'].map(ferquency_mapping2)

# %%
df[['brid' , 'banking_relationship']].head(10)
# Out:
#    brid banking_relationship
# 0     1               Retail
# 1     2        Institutional
# 2     3        Pricvate_Bank
# 3     4           Commercial
# 4     1               Retail
# 5     1               Retail
# 6     1               Retail
# 7     2        Institutional
# 8     2        Institutional
# 9     3        Pricvate_Bank

# %%
df.head(5)
# Out:
#   client_id             name  age  location_id joined_bank   banking_contact  \
# 0  IND81288    Raymond Mills   24        34324  06-05-2019    Anthony Torres
# 1  IND65833    Julia Spencer   23        42205  10-12-2001  Jonathan Hawkins
# 2  IND47499   Stephen Murray   27         7314  25-01-2010     Anthony Berry
# 3  IND72498   Virginia Garza   40        34594  28-03-2019        Steve Diaz
# 4  IND60181  Melissa Sanders   46        41269  20-07-2012        Shawn Long
#
#   nationality            occupation fee_structure loyalty_classification  ...  \
# 0    American  Safety Technician IV          High                   Jade  ...
# 1     African   Software Consultant          High                   Jade  ...
# 2    European    Help Desk Operator          High                   Gold  ...
# 3    American          Geologist II           Mid                 Silver  ...
# 4    American   Assistant Professor           Mid               Platinum  ...
#
# ...

# %%
df = df.drop('brid' , axis = 1)
df = df.drop('genderid' , axis = 1)
df = df.drop('iaid' , axis = 1)

# %%
df.head(5)
# Out:
#   client_id             name  age  location_id joined_bank   banking_contact  \
# 0  IND81288    Raymond Mills   24        34324  06-05-2019    Anthony Torres
# 1  IND65833    Julia Spencer   23        42205  10-12-2001  Jonathan Hawkins
# 2  IND47499   Stephen Murray   27         7314  25-01-2010     Anthony Berry
# 3  IND72498   Virginia Garza   40        34594  28-03-2019        Steve Diaz
# 4  IND60181  Melissa Sanders   46        41269  20-07-2012        Shawn Long
#
#   nationality            occupation fee_structure loyalty_classification  ...  \
# 0    American  Safety Technician IV          High                   Jade  ...
# 1     African   Software Consultant          High                   Jade  ...
# 2    European    Help Desk Operator          High                   Gold  ...
# 3    American          Geologist II           Mid                 Silver  ...
# 4    American   Assistant Professor           Mid               Platinum  ...
#
# ...

# %%
# frequency mapping for risk_weighting

ferquency_mapping3 = {
    1 : 'Very_Low_Risk',
    2 : 'Low_Risk',
    3 : 'Medium_Risk',
    4 : 'High_Risk',
    5 : 'Very_High_Risk'
}

df['risk_sensitivity'] = df['risk_weighting'].map(ferquency_mapping3)

# %%
df[['risk_weighting' , 'risk_sensitivity']].head(5)
# Out:
#    risk_weighting risk_sensitivity
# 0               2         Low_Risk
# 1               3      Medium_Risk
# 2               3      Medium_Risk
# 3               4        High_Risk
# 4               3      Medium_Risk

# %%
df = df.drop('risk_weighting' , axis = 1)

# %%
df.head()
# Out:
#   client_id             name  age  location_id joined_bank   banking_contact  \
# 0  IND81288    Raymond Mills   24        34324  06-05-2019    Anthony Torres
# 1  IND65833    Julia Spencer   23        42205  10-12-2001  Jonathan Hawkins
# 2  IND47499   Stephen Murray   27         7314  25-01-2010     Anthony Berry
# 3  IND72498   Virginia Garza   40        34594  28-03-2019        Steve Diaz
# 4  IND60181  Melissa Sanders   46        41269  20-07-2012        Shawn Long
#
#   nationality            occupation fee_structure loyalty_classification  ...  \
# 0    American  Safety Technician IV          High                   Jade  ...
# 1     African   Software Consultant          High                   Jade  ...
# 2    European    Help Desk Operator          High                   Gold  ...
# 3    American          Geologist II           Mid                 Silver  ...
# 4    American   Assistant Professor           Mid               Platinum  ...
#
# ...

# %%
from sqlalchemy import create_engine 
# 1: Connect to postgerys

username = 'postgres'
password = '1k2e3v4i5N'
host = 'localhost'
port = '5432'
database = "banking_cases"

engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")

#2 : Load Dataframe into PGAdmin

table_name = "banking_customer"
df.to_sql(table_name , engine , if_exists = "replace", index = False)

print(f"Data successfully loaded into table '{table_name}' in database '{database}'.")
# Out:
# Data successfully loaded into table 'banking_customer' in database 'banking_cases'.

# %%
df['risk_weighting'].value_counts()
# Out:
# risk_weighting
# 2    1222
# 1     836
# 3     460
# 4     322
# 5     160
# Name: count, dtype: int64

# %%
df['loyalty_classification'].unique()
# Out:
# array(['Jade', 'Gold', 'Silver', 'Platinum'], dtype=object)

# %%
df['loyalty_classification'].value_counts()
# Out:
# loyalty_classification
# Jade        1331
# Silver       767
# Gold         585
# Platinum     317
# Name: count, dtype: int64
